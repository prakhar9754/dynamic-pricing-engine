# %% [markdown]
# # 📊 Data Understanding - Dynamic Pricing Engine
#
# ### 📌 Project:
# Dynamic Pricing for E-commerce
#
# ### 📂 Dataset:
# Ecommerce Behavior Dataset (Sample)
#
# ### 🎯 Objective:
# To explore and understand the dataset structure, features, and key patterns before preprocessing.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 📂 Load Dataset
# Load the sampled dataset for analysis.

# %%
df = pd.read_csv(r"C:\Users\hp\Desktop\PROJECTS\Dynamic_Pricing_Engine\data\raw\ecommerce_sample.csv")

# %%
df.info()

# %% [markdown]
# ## 👀 Initial Data Overview
#
# Quick look at dataset structure and sample records.

# %%
print(df.head())
print('shape of dataset:',df.shape)

# %% [markdown]
# ## 📊 Statistical Summary
#
# Summary statistics for numerical features.

# %%
df.describe()

# %% [markdown]
# ## 🏷️ Column Description
#
# | Column Name  | Description |
# |-------------|------------|
# | event_time  | Timestamp of user interaction |
# | event_type  | Type of action (view, cart, purchase) |
# | product_id  | Unique product identifier |
# | category_id | Product category |
# | price       | Product price |
# | user_id     | Unique user identifier |

# %% [markdown]
# ## 🔍 Missing Values Analysis
#
# Identify missing data in each column

# %%
df.isnull().sum()

# %% [markdown]
# ## 🔁 Duplicate Records
#
# Check for duplicate entries in dataset.

# %%
df.duplicated().sum()

# %% [markdown]
# ## 📊 Unique Values
#
# Understanding cardinality of key features.

# %%
df.nunique()

# %% [markdown]
# ## 📈 Event Type Distribution
#
# Analyze distribution of user actions.

# %%
df['event_type'].value_counts()

# %% [markdown]
# ## 💰 Price Analysis
#
# Understand pricing distribution.

# %%
df['price'].describe()

# %% [markdown]
# ## 👤 User Behavior Overview
#
# Analyze number of unique users and activity.

# %%
df['user_id'].nunique()

# %% [markdown]
# ## 📦 Product Analysis
#
# Analyze number of unique products.

# %%
df['product_id'].nunique()

# %% [markdown]
# ## 🧠 Key Observations
#
# - Dataset contains user interaction events such as views, cart additions, and purchases
# - High imbalance expected between views and purchases
# - Price distribution may contain outliers
# - Dataset is large but sampled for efficiency
# - User behavior patterns will be critical for demand prediction
